# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   class        891 non-null    category
#  8   who          891 non-null    object
#  9   adult_male   891 non-null    bool
#  10  deck         203 non-null    category
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(4)
# memory usage: 73.7+ KB

# %%
df.fillna({'age': df['age'].median()}, inplace=True)

# %%
(df.isna().sum() / df.shape[0]) * 100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age             0.000000
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.000000
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['age'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['parch'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['pclass'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['sibsp'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['parch'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['pclass'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['fare'],y=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['sex'],estimator='median')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['sex'],estimator=np.std)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['embark_town'],y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['embark_town'],y=df['survived'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['embark_town'],y=df['pclass'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['embark_town'],y=df['sibsp'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['embark_town'],y=df['age'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['embark_town'],y=df['parch'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['embark_town'],y=df['fare'],estimator='mean')
plt.show()

# %%
sns.boxplot(x=df['survived'])
plt.show()

# %%
sns.boxplot(x=df['pclass'])
plt.show()

# %%
sns.boxplot(x=df['age'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'])
plt.show()

# %%
sns.boxplot(x=df['parch'])
plt.show()

# %%
sns.boxplot(x=df['fare'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['deck'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['deck'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['deck'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['deck'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['deck'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['deck'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['alone'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['alone'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['alone'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['alone'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['alone'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['who'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['adult_male'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['deck'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['embark_town'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['who'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['adult_male'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['deck'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['embark_town'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['adult_male'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['deck'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['embark_town'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['deck'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['embark_town'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['deck'],y=df['embark_town'])
plt.show()

# %%
sns.stripplot(x=df['deck'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['deck'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['embark_town'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['embark_town'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['alive'],y=df['alone'])
plt.show()

# %%
sns.swarmplot(x=df['sex'],y=df['class'])
plt.show()
# Out:
# C:\Users\rmnav\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 74.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\rmnav\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 53.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\rmnav\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 86.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\rmnav\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 74.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['age'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['fare'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['pclass'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['pclass'],y=df['fare'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['age'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['parch'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['fare'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['pclass'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['fare'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['pclass'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['fare'],y=df['pclass'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['age'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['parch'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['fare'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['pclass'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['fare'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['pclass'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['fare'],y=df['pclass'],hue=df['who'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['age'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['parch'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['fare'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['pclass'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['fare'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['pclass'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['fare'],y=df['pclass'],hue=df['adult_male'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['age'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['parch'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['fare'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['fare'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['pclass'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['fare'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['pclass'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["fare"],y=df['pclass'],hue=df['deck'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["survived"],y=df['age'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["survived"],y=df['sibsp'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["survived"],y=df['parch'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["survived"],y=df['fare'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["survived"],y=df['pclass'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["age"],y=df['sibsp'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["age"],y=df['parch'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["age"],y=df['fare'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["age"],y=df['pclass'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["sibsp"],y=df['parch'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["sibsp"],y=df['fare'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["sibsp"],y=df['pclass'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["parch"],y=df['fare'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["parch"],y=df['pclass'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["parch"],y=df['pclass'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["fare"],y=df['pclass'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["survived"],y=df['age'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["survived"],y=df['sibsp'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["survived"],y=df['parch'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["survived"],y=df['fare'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["survived"],y=df['pclass'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["age"],y=df['sibsp'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["age"],y=df['parch'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["age"],y=df['fare'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["age"],y=df['pclass'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["sibsp"],y=df['parch'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["sibsp"],y=df['fare'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["sibsp"],y=df['pclass'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["parch"],y=df['fare'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["parch"],y=df['pclass'],hue=df['alive'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df["fare"],y=df['pclass'],hue=df['alive'])
plt.show()
